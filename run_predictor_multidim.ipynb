# %% [markdown]
# Sourced from https://m2lines.github.io/L96_demo/notebooks/intro_ML_and_NNs.html

# %%
# !nvidia-smi
# Out:
# Fri Jan 30 21:13:21 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-PCIE-40GB          On  |   00000000:25:00.0 Off |                    0 |
# | N/A   37C    P0             56W /  250W |     583MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A         3634144      C   ...a3/envs/L96M2lines/bin/python        574MiB |
# +-----------------------------------------------------------------------------------------+

# %%
from m_star_predictor import (
    LinearRegression, FCNN, fit_model, normalize, real_units,
    reduce_dataset, compute_rmse
)
import torch
import torch.utils.data as Data
from torch.utils.data import random_split
from torch import optim
import numpy as np
import os

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

# Ensuring reproducibility
np.random.seed(14)
torch.manual_seed(123);
sklear_random_state = 123

# %%
def calculate_rolling_average(
        data: np.ndarray,
        window_size: int
) -> np.ndarray:
    return np.convolve(np.pad(data, pad_width=int(window_size/2), mode="edge"), np.ones(window_size)/window_size, mode='valid')[:-1]

# %%
if torch.cuda.is_available():
    print("GPU is available.")
    print(f"Number of GPUs: {torch.cuda.device_count()}")
    print(f"Current GPU name: {torch.cuda.get_device_name(0)}")
else:
    print("GPU not available. PyTorch is likely using the CPU.")

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# GPU not available. PyTorch is likely using the CPU.
# Using device: cpu

# %%
mean_vals = True

data_directory = '../m_star_dataset'
# dataset_filename = "ows_papa_2015_dataset_M_target_uv.pt"
dataset_name = 'ePBL_paper_expanded_2283_corrected'
validation_dataset_name = 'ePBL_paper_validation_2283_corrected'
dataset_filename = f"{dataset_name}_mean_dataset_M_target.pt" if mean_vals else f"{dataset_name}_dataset_M_target.pt"
validation_dataset_filename = f"{validation_dataset_name}_mean_dataset_M_target.pt" if mean_vals else f"{validation_dataset_name}_dataset_M_target.pt"
data = torch.load(os.path.join(data_directory, dataset_filename))
validation_data = torch.load(os.path.join(data_directory, validation_dataset_filename))

# %%
X_val, y_val = validation_data.T[:,:-1].float(), validation_data.T[:,-1].unsqueeze(1).float()

# %%
X, y = data.T[:,:-1].float(), data.T[:,-1].unsqueeze(1).float()

# %%
print(X.shape, y.shape)
# Out:
# torch.Size([3240, 4]) torch.Size([3240, 1])

# %%
print(X_val.shape, y_val.shape)
# Out:
# torch.Size([216, 4]) torch.Size([216, 1])

# %%
BATCH_SIZE = 2 ** 4 if mean_vals else 2 ** 12
# BATCH_SIZE = 2 ** 4

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=sklear_random_state
)

X_train_mean = X_train.mean(dim=0)
X_train_std = X_train.std(dim=0)
y_train_mean = y_train.mean(dim=0)
y_train_std = y_train.std(dim=0)

X_train= normalize(X_train, X_train_mean, X_train_std)
X_test =  normalize(X_test, X_train_mean, X_train_std)
y_train = normalize(y_train, y_train_mean, y_train_std)
y_test = normalize(y_test, y_train_mean, y_train_std)

train_dataset = Data.TensorDataset(X_train, y_train)
test_dataset = Data.TensorDataset(X_test, y_test)

train_loader = Data.DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = Data.DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
data_iterator = iter(train_loader)
X_iter, subgrid_tend_iter = next(data_iterator)

plt.plot(X_iter, subgrid_tend_iter, '.')
# Out:
# [<matplotlib.lines.Line2D at 0x14e44798c100>,
#  <matplotlib.lines.Line2D at 0x14e44798c160>,
#  <matplotlib.lines.Line2D at 0x14e44798c2b0>,
#  <matplotlib.lines.Line2D at 0x14e44798c370>]

# %%
linear_network = LinearRegression(input_size=4)
fcnn_network = FCNN(input_size=4)

# %%
loss_fn = torch.nn.MSELoss()

# %%
learning_rate = 0.003
momentum = 0.1
weight_decay = 0

# %%
optimizer_linear = optim.Adam(
    linear_network.parameters(), lr=learning_rate, weight_decay=weight_decay
)
optimizer_fcnn = optim.Adam(
    fcnn_network.parameters(), lr=learning_rate, weight_decay=weight_decay
)

# %%
n_epochs = 600

# %%
train_loss_linear, test_loss_linear = fit_model(
    linear_network, loss_fn, optimizer_linear, train_loader, test_loader, n_epochs, device
)
# Out:
# epoch 1 completed
# epoch 2 completed
# epoch 3 completed
# epoch 4 completed
# epoch 5 completed
# epoch 6 completed
# epoch 7 completed
# epoch 8 completed
# epoch 9 completed
# epoch 10 completed
# epoch 11 completed
# epoch 12 completed
# epoch 13 completed
# epoch 14 completed
# epoch 15 completed
# epoch 16 completed
# epoch 17 completed
# epoch 18 completed
# epoch 19 completed
# epoch 20 completed
# epoch 21 completed
# epoch 22 completed
# epoch 23 completed
# epoch 24 completed
# epoch 25 completed
# epoch 26 completed
# epoch 27 completed
# epoch 28 completed
# epoch 29 completed
# epoch 30 completed
# epoch 31 completed
# epoch 32 completed
# epoch 33 completed
# epoch 34 completed
# epoch 35 completed
# epoch 36 completed
# epoch 37 completed
# epoch 38 completed
# epoch 39 completed
# epoch 40 completed
# epoch 41 completed
# epoch 42 completed
# epoch 43 completed
# epoch 44 completed
# epoch 45 completed
# epoch 46 completed
# epoch 47 completed
# epoch 48 completed
# epoch 49 completed
# epoch 50 completed
# epoch 51 completed
# epoch 52 completed
# epoch 53 completed
# epoch 54 completed
# epoch 55 completed
# epoch 56 completed
# epoch 57 completed
# epoch 58 completed
# epoch 59 completed
# epoch 60 completed
# epoch 61 completed
# epoch 62 completed
# epoch 63 completed
# epoch 64 completed
# epoch 65 completed
# epoch 66 completed
# epoch 67 completed
# epoch 68 completed
# epoch 69 completed
# epoch 70 completed
# epoch 71 completed
# epoch 72 completed
# epoch 73 completed
# epoch 74 completed
# epoch 75 completed
# epoch 76 completed
# epoch 77 completed
# epoch 78 completed
# epoch 79 completed
# epoch 80 completed
# epoch 81 completed
# epoch 82 completed
# epoch 83 completed
# epoch 84 completed
# epoch 85 completed
# epoch 86 completed
# epoch 87 completed
# epoch 88 completed
# epoch 89 completed
# epoch 90 completed
# epoch 91 completed
# epoch 92 completed
# epoch 93 completed
# epoch 94 completed
# epoch 95 completed
# epoch 96 completed
# epoch 97 completed
# epoch 98 completed
# epoch 99 completed
# epoch 100 completed
# epoch 101 completed
# epoch 102 completed
# epoch 103 completed
# epoch 104 completed
# epoch 105 completed
# epoch 106 completed
# epoch 107 completed
# epoch 108 completed
# epoch 109 completed
# epoch 110 completed
# epoch 111 completed
# epoch 112 completed
# epoch 113 completed
# epoch 114 completed
# epoch 115 completed
# epoch 116 completed
# epoch 117 completed
# epoch 118 completed
# epoch 119 completed
# epoch 120 completed
# epoch 121 completed
# epoch 122 completed
# epoch 123 completed
# epoch 124 completed
# epoch 125 completed
# epoch 126 completed
# epoch 127 completed
# epoch 128 completed
# epoch 129 completed
# epoch 130 completed
# epoch 131 completed
# epoch 132 completed
# epoch 133 completed
# epoch 593 completed
# epoch 594 completed
# epoch 595 completed
# epoch 596 completed
# epoch 597 completed
# epoch 598 completed
# epoch 599 completed
# epoch 600 completed
# Training completed in 41 seconds.

# %%
train_loss_fcnn, test_loss_fcnn = fit_model(
    fcnn_network, loss_fn, optimizer_fcnn, train_loader, test_loader, n_epochs, device
)
# Out:
# epoch 1 completed
# epoch 2 completed
# epoch 3 completed
# epoch 4 completed
# epoch 5 completed
# epoch 6 completed
# epoch 7 completed
# epoch 8 completed
# epoch 9 completed
# epoch 10 completed
# epoch 11 completed
# epoch 12 completed
# epoch 13 completed
# epoch 14 completed
# epoch 15 completed
# epoch 16 completed
# epoch 17 completed
# epoch 18 completed
# epoch 19 completed
# epoch 20 completed
# epoch 21 completed
# epoch 22 completed
# epoch 23 completed
# epoch 24 completed
# epoch 25 completed
# epoch 26 completed
# epoch 27 completed
# epoch 28 completed
# epoch 29 completed
# epoch 30 completed
# epoch 31 completed
# epoch 32 completed
# epoch 33 completed
# epoch 34 completed
# epoch 35 completed
# epoch 36 completed
# epoch 37 completed
# epoch 38 completed
# epoch 39 completed
# epoch 40 completed
# epoch 41 completed
# epoch 42 completed
# epoch 43 completed
# epoch 44 completed
# epoch 45 completed
# epoch 46 completed
# epoch 47 completed
# epoch 48 completed
# epoch 49 completed
# epoch 50 completed
# epoch 51 completed
# epoch 52 completed
# epoch 53 completed
# epoch 54 completed
# epoch 55 completed
# epoch 56 completed
# epoch 57 completed
# epoch 58 completed
# epoch 59 completed
# epoch 60 completed
# epoch 61 completed
# epoch 62 completed
# epoch 63 completed
# epoch 64 completed
# epoch 65 completed
# epoch 66 completed
# epoch 67 completed
# epoch 68 completed
# epoch 69 completed
# epoch 70 completed
# epoch 71 completed
# epoch 72 completed
# epoch 73 completed
# epoch 74 completed
# epoch 75 completed
# epoch 76 completed
# epoch 77 completed
# epoch 78 completed
# epoch 79 completed
# epoch 80 completed
# epoch 81 completed
# epoch 82 completed
# epoch 83 completed
# epoch 84 completed
# epoch 85 completed
# epoch 86 completed
# epoch 87 completed
# epoch 88 completed
# epoch 89 completed
# epoch 90 completed
# epoch 91 completed
# epoch 92 completed
# epoch 93 completed
# epoch 94 completed
# epoch 95 completed
# epoch 96 completed
# epoch 97 completed
# epoch 98 completed
# epoch 99 completed
# epoch 100 completed
# epoch 101 completed
# epoch 102 completed
# epoch 103 completed
# epoch 104 completed
# epoch 105 completed
# epoch 106 completed
# epoch 107 completed
# epoch 108 completed
# epoch 109 completed
# epoch 110 completed
# epoch 111 completed
# epoch 112 completed
# epoch 113 completed
# epoch 114 completed
# epoch 115 completed
# epoch 116 completed
# epoch 117 completed
# epoch 118 completed
# epoch 119 completed
# epoch 120 completed
# epoch 121 completed
# epoch 122 completed
# epoch 123 completed
# epoch 124 completed
# epoch 125 completed
# epoch 126 completed
# epoch 127 completed
# epoch 128 completed
# epoch 129 completed
# epoch 130 completed
# epoch 131 completed
# epoch 132 completed
# epoch 133 completed
# epoch 134 completed
# epoch 135 completed
# epoch 136 completed
# epoch 596 completed
# epoch 597 completed
# epoch 598 completed
# epoch 599 completed
# epoch 600 completed
# Training completed in 63 seconds.

# %%
plt.figure(dpi=150)

plt.plot(train_loss_linear, label="Linear train loss")
plt.plot(test_loss_linear, linestyle="--", label="Linear test loss")

plt.plot(train_loss_fcnn, label="FCNN train loss")
plt.plot(test_loss_fcnn, linestyle="--", label="FCNN test loss")

plt.legend()
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.yscale("log")
plt.title("Loss vs Iteration")
plt.show();

# %%
plt.figure(figsize=(5,3), tight_layout=True)
plt.plot(train_loss_fcnn, color="#c2dbf3", label=f"_no_label_")
plt.plot(test_loss_fcnn, color="#c2dbf3", label=f"_no_label_")
plt.plot(calculate_rolling_average(train_loss_fcnn, 10), color="black", label=f"FCNN_mean train loss")
plt.plot(calculate_rolling_average(test_loss_fcnn, 10), color="black", linestyle="dashed", label=f"FCNN_mean test loss")
plt.gca().set_yscale("log")
plt.legend()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.ylabel("MSE Loss")
plt.xlabel("Epoch")

plt.savefig("mean_predictor_training_trajectory.png", dpi=600)

# %%
# TODO: build function to plot true and predicted m*

# %%
fcnn_traj_save_path = 'm_star_predictors/fcnn_mean_predictor_train_test_loss.npy'
np.save(fcnn_traj_save_path, np.array([train_loss_fcnn, test_loss_fcnn]))  # re-run default and ysqrt because I didn't save them :))))

# %%
fcnn_train_prediction = fcnn_network(X_train)*y_train_std+y_train_mean
linear_train_prediction = linear_network(X_train)*y_train_std+y_train_mean

fcnn_test_prediction = fcnn_network(X_test)*y_train_std+y_train_mean
linear_test_prediction = linear_network(X_test)*y_train_std+y_train_mean

y_train_real_units = y_train*y_train_std+y_train_mean
y_test_real_units = y_test*y_train_std+y_train_mean

# X_val_normalized = (X_val - X_train_mean) / X_train_std
# fcnn_val_prediction = fcnn_network(X_val_normalized)*y_train_std+y_train_mean
# linear_val_prediction = linear_network(X_val_normalized)*y_train_std+y_train_mean

# %%
fcnn_save_path = 'm_star_predictors/fcnn_mean_predictor_weights.pth'
linear_save_path = 'm_star_predictors/linear_mean_predictor_weights.pth'
torch.save(fcnn_network.state_dict(), fcnn_save_path)
torch.save(linear_network.state_dict(), linear_save_path)

# %%
xs, ys = np.linspace(0., 2e-5, 1000), np.linspace(0., 2e-5, 1000)

fig, ax = plt.subplots(1,1,figsize=(3,3))
ax.scatter(fcnn_test_prediction.detach().numpy(), y_test_real_units, color="black", s=1, alpha=.2,)
ax.scatter(fcnn_train_prediction.detach().numpy(), y_train_real_units, color="black", s=1, alpha=.2)
ax.plot(xs, ys, color="#f15a29", linestyle="dashed", linewidth=0.8)
ax.set_yticks([1e-5, 2e-5])
ax.set_xticks([0, 1e-5, 2e-5])
ax.set_xlim(0, 2.2e-5)
ax.set_ylim(0, 2.2e-5)
ax.set_ylabel("$M_{true}$ [m$^3$ s$^{-3}$]")
ax.set_xlabel("$M_{pred}$ [m$^3$ s$^{-3}$]")
ax.ticklabel_format(style='sci', useMathText=True, scilimits=(-2, 2), axis='both')

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

fig.tight_layout()

plt.savefig("mean_M_true_pred_mean_predictor.png", dpi=600)

# %%
xs, ys = np.linspace(0., 2e-5, 1000), np.linspace(0., 2e-5, 1000)

plt.figure(figsize=(4,4))
plt.scatter(fcnn_test_prediction.detach().numpy(), y_test_real_units, color="orange", s=1, alpha=.4)
plt.scatter(fcnn_train_prediction.detach().numpy(), y_train_real_units, color="red", s=1, alpha=.4)
plt.plot(xs, ys, color="black", linestyle="dashed", linewidth=0.5)
plt.ylabel("$M_{true}$")
plt.xlabel("$M_{pred}$")
# plt.ylim(-.5,3.5)
# plt.xlim(-.5,3.5)

# plt.savefig("inst_M_true_pred_with_utau.png", dpi=300)
# Out:
# Text(0.5, 0, '$M_{pred}$')

# %%
X_val_normalized = (X_val[:,:4] - X_train_mean) / X_train_std
fcnn_val_prediction = fcnn_network(X_val_normalized)*y_train_std+y_train_mean

# %%
fig, ax = plt.subplots(1,2, figsize=(7,3))

ax[0].hist(X[:,2].detach().numpy(), 9, color="black", ec="white")
# ax[0].set_xlabel("$u_*$ [ms$^{-1}$]")
ax[1].hist(X_val[:,2].detach().numpy(), 9, color="black", ec="white")
# ax[1].set_xlabel("$H_{bl}$ [m]")

fig.tight_layout()

# %%
fig, ax = plt.subplots(1,2, figsize=(7,3))

ax[0].hist(np.sqrt(y.detach().numpy()), 9, color="black", ec="white")
# ax[0].set_xlabel("$u_*$ [ms$^{-1}$]")
ax[1].hist(np.sqrt(y_val.detach().numpy()), 9, color="black", ec="white")
# ax[1].set_xlabel("$H_{bl}$ [m]")

fig.tight_layout()

# %%
xs, ys = np.linspace(0., 6e-5, 1000), np.linspace(0., 6e-5, 1000)

plt.figure(figsize=(4,4))
plt.scatter(fcnn_val_prediction.detach().numpy(), y_val, color="black", s=1, alpha=.4)
plt.plot(xs, ys, color="red", linestyle="dashed")
plt.ylabel("$M_{true}$")
plt.xlabel("$M_{pred}$")
# Out:
# Text(0.5, 0, '$M_{pred}$')

# %%
np.sqrt(np.mean((fcnn_test_prediction.detach().numpy()-y_test_real_units.detach().numpy())**2))
# Out:
# 5.4636065e-08

# %%
np.sqrt(np.mean((fcnn_train_prediction.detach().numpy()-y_train_real_units.detach().numpy())**2))
# Out:
# 4.7224304e-08

# %%
np.sqrt(np.mean((fcnn_val_prediction.detach().numpy()-y_val.detach().numpy())**2))
# Out:
# 2.0942326e-07

# %%
import json

with open(os.path.join(data_directory, f'{dataset_name}_training_set_dropped_cases.json'), 'r') as file:
    gotm_dropped_case_dict = json.load(file)

# %%
cases_to_drop = np.load(os.path.join(data_directory, f'{dataset_name}_dropped_cases.npy'))

# %%
for i in cases_to_drop[:30]:
    case_specs = gotm_dropped_case_dict[f"case_{i+1}"]
    tg, tx, lat, hf = case_specs['temp_grad'], case_specs['tx'], case_specs['lat'], case_specs['heat_flux']
    plt.figure(tight_layout=True)
    plt.title(f"temp_grad: {tg}, tx: {tx}, lat: {lat}, hf: {hf}")
    plt.plot(fcnn_val_prediction.detach().numpy()[433*i:433*(i+1)], label="M$_{pred}$", color="red")
    plt.plot(y_val[433*i:433*(i+1)], label="M$_{true}$", color="black")
    plt.xlabel("Time step [30 min]")
    plt.ylabel("M")
    plt.legend()
# Out:
# /tmp/ipykernel_165606/3046402075.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(tight_layout=True)
